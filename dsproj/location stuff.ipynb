# %%
import pandas as pd

# Load the CSV file
file_path = 'content/distinct_buildings excel.csv'  # Adjust the file path if needed
data = pd.read_csv(file_path, delimiter=';')

# Check if 'location' column exists
if 'location' in data.columns:
    # Split the 'location' column into 'latitude' and 'longitude'
    data[['latitude', 'longitude']] = data['location'].str.split(',', expand=True)

    # Optionally, you can drop the original 'location' column
    data.drop(columns=['location'], inplace=True)
    data.drop(columns=['Column1'], inplace=True)
    data.rename(columns={
    'building': 'building_code'}, inplace=True)
    # Save the modified DataFrame to a new CSV file
    new_file_path = 'content/distinct_buildings_modified.csv'
    data.to_csv(new_file_path, index=False, sep=';')

    print("File processed and saved as:", new_file_path)
else:
    print("The 'location' column was not found in the CSV file.")
# Out:
# File processed and saved as: content/distinct_buildings_modified.csv

# %%
data
# Out:
#    building_code            latitude            longitude
# 0             ZI   52.23920253719435    6.856910817479597
# 1             CR   52.23816328226085    6.857637461359666
# 2             HT   52.23761533457211    6.860704629276648
# 3             RA  52.239394466454705    6.855659446986793
# 4             CU    52.2404747275504    6.856748790412035
# 5             SP   52.23967014713761    6.849788127854926
# 6             SC   52.24387520603568    6.850267866916351
# 7             NH   52.23808480549669    6.861725240099451
# 8             OH   52.23695706050182    6.861045395561615
# 9             HB   52.23872999804916    6.857130329481763
# 10            WA   52.23847743019222   6.8563891284821175
# 11            WH   52.23871000853758    6.859747131536082
# 12            HR   52.23762429639754    6.860899781564861
# 13            VR   52.24380877424921    6.853376992143756
# 14            CI   52.23889678656126    6.855166303367093
# 15            EX   52.23889678656126    6.855166303367093
# 16            GY  52.237232702978964   6.8550384228553325
# 17            TH  52.236476928219574    6.843190805386873

# %%
from sqlalchemy import create_engine
import pandas as pd

driver = 'postgresql'
username = 'dab_ds23241a_123'
dbname = username  # it is the same as the username
password = 'BdleaEuFH036h8hi'
server = 'bronto.ewi.utwente.nl'
port = '5432'
# Creating the connection pool for SQL
engine = create_engine(f'{driver}://{username}:{password}@{server}:{port}/{dbname}?client_encoding=utf8')

sql_query = 'SELECT * FROM timetables.activities'

# Use pandas to execute the query and load results into a DataFrame
activities = pd.read_sql_query(sql_query, engine)

# %%
activities
# Out:
#        course_code                                 activity_name start_time  \
# 0        191210750              1B System-on-chip-Design/HC01/01   08:45:00
# 1        191210750              1B System-on-chip-Design/HC01/01   08:45:00
# 2        191210750              1B System-on-chip-Design/HC05/01   08:45:00
# 3        191210750              1B System-on-chip-Design/HC05/01   08:45:00
# 4        191210750              1B System-on-chip-Design/HC02/01   13:45:00
# ...            ...                                           ...        ...
# 147743   201600172                              Project/PRS01/01   10:45:00
# 147744   201600198    Molecular spectroscopy for imaging/HC01/01   13:45:00
# 147745   201600198         Magnetic Resonance Imaging/TOETS02/01   08:45:00
# 147746   201600198  Molecular spectroscopy for imaging/RESP01/01   10:45:00
# 147747   201600198        Project Imaging & Diagnostics/PRS01/01   09:45:00
#
#         end_time  year                   activity_description activity_type  \
# 0       12:30:00  2013        191210750 System-on-chip-Design           PRA
# 1       12:30:00  2013        191210750 System-on-chip-Design           PRA
# 2       12:30:00  2013        191210750 System-on-chip-Design           PRA
# 3       12:30:00  2013        191210750 System-on-chip-Design           PRA
# 4       17:30:00  2013        191210750 System-on-chip-Design           PRA
# ...          ...   ...                                    ...           ...
# 147743  12:30:00  2016                                Project           PRS
# 147744  15:30:00  2016     Molecular spectroscopy for imaging            HC
# 147745  11:45:00  2016             Magnetic Resonance Imaging         TOETS
# 147746  12:30:00  2016     Molecular spectroscopy for imaging           RES
# 147747  12:30:00  2016  Project Project Imaging & Diagnostics           PRS
#
#         duration        date        room building_code program_code  \
# 0           3.75  2013-11-11       ZI W3            ZI         EE M
# 1           3.75  2013-11-11       ZI W4            ZI         EE M
# 2           3.75  2013-11-18       ZI W3            ZI         EE M
# 3           3.75  2013-11-18       ZI W4            ZI         EE M
# 4           3.75  2013-11-11       ZI W3            ZI         EE M
# ...          ...         ...         ...           ...          ...
# 147743      1.75  2017-02-03        SP 2            SP        IBA B
# 147744      1.75  2016-11-14       HB 2B            HB        BMT B
# 147745      3.00  2017-01-13  ZZ CR 2G/T            CR        BMT B
# 147746      1.75  2017-01-23       HB 2B            HB        BMT B
# 147747      2.75  2017-02-02       CR 3A            CR        BMT B
#
#         distance_to_next_activity_km
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 147743                           NaN
# 147744                           NaN
# 147745                           NaN
# 147746                           NaN
# 147747                           NaN
#
# [147748 rows x 13 columns]

# %%
activities = activities.merge(data, left_on='building_code', right_on='building_code', how='left')

# %%
activities
# Out:
#        course_code                                 activity_name start_time  \
# 0        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 1        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 2        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 3        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 4        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# ...            ...                                           ...        ...
# 147743   201600198         Magnetic Resonance Imaging/TOETS02/01   08:45:00
# 147744   201600198  Molecular spectroscopy for imaging/RESP01/01   10:45:00
# 147745   201600198  Molecular spectroscopy for imaging/RESP01/01   10:45:00
# 147746   201600198        Project Imaging & Diagnostics/PRS01/01   09:45:00
# 147747   201600198        Project Imaging & Diagnostics/PRS01/01   09:45:00
#
#         end_time  year                   activity_description activity_type  \
# 0       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 1       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 2       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 3       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 4       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# ...          ...   ...                                    ...           ...
# 147743  11:45:00  2016             Magnetic Resonance Imaging         TOETS
# 147744  12:30:00  2016     Molecular spectroscopy for imaging           RES
# 147745  12:30:00  2016     Molecular spectroscopy for imaging           RES
# 147746  12:30:00  2016  Project Project Imaging & Diagnostics           PRS
# 147747  12:30:00  2016  Project Project Imaging & Diagnostics           PRS
#
#         duration        date        room building_code program_code  \
# 0           8.75  2014-07-07      OH 215            OH         IO B
# 1           8.75  2014-07-07      OH 215            OH         IO B
# 2           8.75  2014-07-07      OH 215            OH         IO B
# 3           8.75  2014-07-07      OH 215            OH         IO B
# 4           8.75  2014-07-07      OH 215            OH         IO B
# ...          ...         ...         ...           ...          ...
# 147743      3.00  2017-01-13  ZZ CR 2G/T            CR        BMT B
# 147744      1.75  2017-01-23       HB 2B            HB        BMT B
# 147745      1.75  2017-01-23       HB 2B            HB        BMT B
# 147746      2.75  2017-02-02       CR 3A            CR        BMT B
# 147747      2.75  2017-02-02       CR 3A            CR        BMT B
#
#         distance_to_next_activity_km           latitude           longitude
# 0                                NaN  52.23695706050182   6.861045395561615
# 1                                NaN  52.23695706050182   6.861045395561615
# 2                                NaN  52.23695706050182   6.861045395561615
# 3                                0.0  52.23695706050182   6.861045395561615
# 4                                0.0  52.23695706050182   6.861045395561615
# ...                              ...                ...                 ...
# 147743                           NaN  52.23816328226085   6.857637461359666
# 147744                           NaN  52.23872999804916   6.857130329481763
# 147745                           NaN  52.23872999804916   6.857130329481763
# 147746                           NaN  52.23816328226085   6.857637461359666
# 147747                           NaN  52.23816328226085   6.857637461359666
#
# [147748 rows x 15 columns]

# %%
# import pandas as pd
# from geopy.distance import geodesic
#
# # Assuming 'activities_df' is your DataFrame with the activities data
# # Make sure to load or define 'activities_df' here if it's not already loaded
#
# # First, sort the DataFrame to ensure activities are ordered correctly
# activities.sort_values(by=['course_code', 'program_code', 'year', 'date', 'start_time'], inplace=True)
#
# # Function to calculate distances
# def calculate_distances(row, next_row):
#     # Check if the next activity meets the criteria to calculate distance
#     if (row['course_code'] == next_row['course_code'] and
#         row['program_code'] == next_row['program_code'] and
#         row['year'] == next_row['year'] and
#         row['date'] == next_row['date']):
#         # Calculate and return the distance
#         return geodesic((row['latitude'], row['longitude']), (next_row['latitude'], next_row['longitude'])).kilometers
#     # Return None or 0 if criteria are not met
#     return None
#
# # Initialize a list to store calculated distances
# distances = []
#
# # Iterate through the DataFrame
# for i in range(len(activities) - 1):
#     # Calculate distance to next activity if criteria are met
#     distance = calculate_distances(activities.iloc[i], activities.iloc[i + 1])
#     distances.append(distance)
#
# # Append None for the last activity of each set, as it has no next activity
# distances.append(None)
#
# # Assign calculated distances to the DataFrame
# activities['distance_to_next_activity_km'] = distances
#
# # Optionally, save the updated DataFrame to a new CSV file
# new_file_path = 'updated_activities_with_distances.csv'
# activities.to_csv(new_file_path, index=False, sep=';')
#
# print("Updated file processed and saved as:", new_file_path)
# Out:
# Updated file processed and saved as: updated_activities_with_distances.csv

# %%
from geopy.distance import geodesic
# # First, sort the DataFrame to ensure activities are ordered correctly
activities.sort_values(by=['course_code', 'program_code', 'year', 'date', 'start_time'], inplace=True)

def calculate_distances(row, next_row):
    # Check if the next activity meets the criteria to calculate distance
    if (row['course_code'] == next_row['course_code'] and
        row['program_code'] == next_row['program_code'] and
        row['year'] == next_row['year'] and
        row['date'] == next_row['date']):

        # Check if consecutive activities have the same description
        if row['activity_description'] == next_row['activity_description']:
            return None  # Set distance to None if descriptions match

        # Calculate and return the distance
        return geodesic((row['latitude'], row['longitude']),
                        (next_row['latitude'], next_row['longitude'])).kilometers
    # Return None if criteria for same course, program, year, and date are not met
    return None

# Initialize a list to store calculated distances
distances = []

# Iterate through the DataFrame
for i in range(len(activities) - 1):
    # Calculate distance to next activity if criteria are met
    distance = calculate_distances(activities.iloc[i], activities.iloc[i + 1])
    distances.append(distance)

# Append None for the last activity of each set, as it has no next activity
distances.append(None)

# Assign calculated distances to the DataFrame
activities['distance_to_next_activity_km'] = distances

# %%
activities
# Out:
#        course_code                                 activity_name start_time  \
# 0        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 1        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 2        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 3        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# 4        191100010                3B TRIZ - Fundamentals/HC01/01   08:45:00
# ...            ...                                           ...        ...
# 147743   201600198         Magnetic Resonance Imaging/TOETS02/01   08:45:00
# 147744   201600198  Molecular spectroscopy for imaging/RESP01/01   10:45:00
# 147745   201600198  Molecular spectroscopy for imaging/RESP01/01   10:45:00
# 147746   201600198        Project Imaging & Diagnostics/PRS01/01   09:45:00
# 147747   201600198        Project Imaging & Diagnostics/PRS01/01   09:45:00
#
#         end_time  year                   activity_description activity_type  \
# 0       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 1       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 2       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 3       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# 4       17:30:00  2013          TRIZ - Fundamentals 191100010            HC
# ...          ...   ...                                    ...           ...
# 147743  11:45:00  2016             Magnetic Resonance Imaging         TOETS
# 147744  12:30:00  2016     Molecular spectroscopy for imaging           RES
# 147745  12:30:00  2016     Molecular spectroscopy for imaging           RES
# 147746  12:30:00  2016  Project Project Imaging & Diagnostics           PRS
# 147747  12:30:00  2016  Project Project Imaging & Diagnostics           PRS
#
#         duration        date        room building_code program_code  \
# 0           8.75  2014-07-07      OH 215            OH         IO B
# 1           8.75  2014-07-07      OH 215            OH         IO B
# 2           8.75  2014-07-07      OH 215            OH         IO B
# 3           8.75  2014-07-07      OH 215            OH         IO B
# 4           8.75  2014-07-07      OH 215            OH         IO B
# ...          ...         ...         ...           ...          ...
# 147743      3.00  2017-01-13  ZZ CR 2G/T            CR        BMT B
# 147744      1.75  2017-01-23       HB 2B            HB        BMT B
# 147745      1.75  2017-01-23       HB 2B            HB        BMT B
# 147746      2.75  2017-02-02       CR 3A            CR        BMT B
# 147747      2.75  2017-02-02       CR 3A            CR        BMT B
#
#         distance_to_next_activity_km           latitude           longitude
# 0                                NaN  52.23695706050182   6.861045395561615
# 1                                NaN  52.23695706050182   6.861045395561615
# 2                                NaN  52.23695706050182   6.861045395561615
# 3                                NaN  52.23695706050182   6.861045395561615
# 4                                NaN  52.23695706050182   6.861045395561615
# ...                              ...                ...                 ...
# 147743                           NaN  52.23816328226085   6.857637461359666
# 147744                           NaN  52.23872999804916   6.857130329481763
# 147745                           NaN  52.23872999804916   6.857130329481763
# 147746                           NaN  52.23816328226085   6.857637461359666
# 147747                           NaN  52.23816328226085   6.857637461359666
#
# [147748 rows x 15 columns]

# %%
activities = activities.drop('latitude',axis=1)

activities = activities.drop('longitude',axis=1)

# %%
activities

# %%
from sqlalchemy import create_engine

driver = 'postgresql'
username = 'dab_ds23241a_123'
dbname = username  # it is the same as the username
password = 'BdleaEuFH036h8hi'
server = 'bronto.ewi.utwente.nl'
port = '5432'
# Creating the connection pool for SQL
engine = create_engine(f'{driver}://{username}:{password}@{server}:{port}/{dbname}?client_encoding=utf8')

# data.to_sql('buildings', con=engine, schema='timetables', if_exists='append', index=False, method='multi')
# activities.to_sql('activities', con=engine, schema='timetables', if_exists='append', index=False, method='multi')
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _exec_insertmany_context(self, dialect, context)
#    2112                 else:
# -> 2113                     dialect.do_execute(
#    2114                         cursor,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     921     def do_execute(self, cursor, statement, parameters, context=None):
# --> 922         cursor.execute(statement, parameters)
#     923
#
# UndefinedColumn: column "latitude" of relation "activities" does not exist
# LINE 1: ...code, program_code, distance_to_next_activity_km, latitude, ...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38260\1175887710.py in <module>
#      11
#      12 # data.to_sql('buildings', con=engine, schema='timetables', if_exists='append', index=False, method='multi')
# ---> 13 activities.to_sql('activities', con=engine, schema='timetables', if_exists='append', index=False, method='multi')
#      14
#      15
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3079         from pandas.io import sql
#    3080
# -> 3081         return sql.to_sql(
#    3082             self,
#    3083             name,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2019         )
#    2020
# -> 2021         total_inserted = sql_engine.insert_records(
#    2022             table=table,
#    2023             con=self.con,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568             if re.search(msg, err_text):
#    1569                 raise ValueError("inf cannot be used with MySQL") from err
# -> 1570             raise err
#    1571
#    1572
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1559
#    1560         try:
# -> 1561             return table.insert(chunksize=chunksize, method=method)
#    1562         except exc.StatementError as err:
#    1563             # GH34431
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#    1120
#    1121                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1122                 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123                 # GH 46891
#    1124                 if num_inserted is not None:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in _execute_insert_multi(self, conn, keys, data_iter)
#    1028         # isn't supported by Oracle.
#    1029         # see: https://docs.sqlalchemy.org/en/20/core/dml.html#sqlalchemy.sql.expression.Insert.values
# -> 1030         result = conn.execute(stmt, data)
#    1031         return result.rowcount
#    1032
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, parameters, execution_options)
#    1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
# -> 1416             return meth(
#    1417                 self,
#    1418                 distilled_parameters,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, distilled_params, execution_options)
#     515             if TYPE_CHECKING:
#     516                 assert isinstance(self, Executable)
# --> 517             return connection._execute_clauseelement(
#     518                 self, distilled_params, execution_options
#     519             )
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1637             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638         )
# -> 1639         ret = self._execute_context(
#    1640             dialect,
#    1641             dialect.execution_ctx_cls._init_compiled,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841
#    1842         if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1843             return self._exec_insertmany_context(
#    1844                 dialect,
#    1845                 context,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _exec_insertmany_context(self, dialect, context)
#    2119
#    2120             except BaseException as e:
# -> 2121                 self._handle_dbapi_exception(
#    2122                     e,
#    2123                     sql_util._long_statement(sub_stmt),
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342             elif should_wrap:
#    2343                 assert sqlalchemy_exception is not None
# -> 2344                 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345             else:
#    2346                 assert exc_info[1] is not None
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _exec_insertmany_context(self, dialect, context)
#    2111                         break
#    2112                 else:
# -> 2113                     dialect.do_execute(
#    2114                         cursor,
#    2115                         sub_stmt,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     920
#     921     def do_execute(self, cursor, statement, parameters, context=None):
# --> 922         cursor.execute(statement, parameters)
#     923
#     924     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "latitude" of relation "activities" does not exist
# LINE 1: ...code, program_code, distance_to_next_activity_km, latitude, ...
#                                                              ^
#
# [SQL: INSERT INTO timetables.activities (course_code, activity_name, start_time, end_time, year, activity_description, activity_type, duration, date, room, building_code, program_code, distance_to_next_activity_km, latitude, longitude) VALUES (%(course_cod ... 330235 characters truncated ... %(program_code__999)s, %(distance_to_next_activity_km__999)s, %(latitude__999)s, %(longitude__999)s)]
# [parameters: {'latitude__0': '52.23695706050182', 'activity_description__0': 'TRIZ - Fundamentals 191100010', 'date__0': datetime.date(2014, 7, 7), 'activity_name__0': '3B TRIZ - Fundamentals/HC01/01', 'program_code__0': 'IO B', 'distance_to_next_activity_km__0': None, 'activity_type__0': 'HC', 'longitude__0': ' 6.861045395561615', 'room__0': 'OH 215', 'building_code__0': 'OH', 'start_time__0': datetime.time(8, 45), 'year__0': '2013', 'course_code__0': '191100010', 'duration__0': 8.75, 'end_time__0': datetime.time(17, 30), 'latitude__1': '52.23695706050182', 'activity_description__1': 'TRIZ - Fundamentals 191100010', 'date__1': datetime.date(2014, 7, 7), 'activity_name__1': '3B TRIZ - Fundamentals/HC01/01', 'program_code__1': 'IO B', 'distance_to_next_activity_km__1': None, 'activity_type__1': 'HC', 'longitude__1': ' 6.861045395561615', 'room__1': 'OH 215', 'building_code__1': 'OH', 'start_time__1': datetime.time(8, 45), 'year__1': '2013', 'course_code__1': '191100010', 'duration__1': 8.75, 'end_time__1': datetime.time(17, 30), 'latitude__2': '52.23695706050182', 'activity_description__2': 'TRIZ - Fundamentals 191100010', 'date__2': datetime.date(2014, 7, 7), 'activity_name__2': '3B TRIZ - Fundamentals/HC01/01', 'program_code__2': 'IO B', 'distance_to_next_activity_km__2': None, 'activity_type__2': 'HC', 'longitude__2': ' 6.861045395561615', 'room__2': 'OH 215', 'building_code__2': 'OH', 'start_time__2': datetime.time(8, 45), 'year__2': '2013', 'course_code__2': '191100010', 'duration__2': 8.75, 'end_time__2': datetime.time(17, 30), 'latitude__3': '52.23695706050182', 'activity_description__3': 'TRIZ - Fundamentals 191100010', 'date__3': datetime.date(2014, 7, 7), 'activity_name__3': '3B TRIZ - Fundamentals/HC01/01', 'program_code__3': 'IO B' ... 14900 parameters truncated ... 'start_time__996': datetime.time(15, 45), 'year__996': '2013', 'course_code__996': '191103250', 'duration__996': 1.75, 'end_time__996': datetime.time(17, 30), 'latitude__997': '52.23761533457211', 'activity_description__997': 'Project F 191103250', 'date__997': datetime.date(2014, 3, 24), 'activity_name__997': '2A Project F/HC04/01', 'program_code__997': 'WB B', 'distance_to_next_activity_km__997': None, 'activity_type__997': 'HC', 'longitude__997': ' 6.860704629276648', 'room__997': 'HT 1100', 'building_code__997': 'HT', 'start_time__997': datetime.time(15, 45), 'year__997': '2013', 'course_code__997': '191103250', 'duration__997': 1.75, 'end_time__997': datetime.time(17, 30), 'latitude__998': '52.23761533457211', 'activity_description__998': 'Project F 191103250', 'date__998': datetime.date(2014, 3, 24), 'activity_name__998': '2A Project F/HC04/01', 'program_code__998': 'WB B', 'distance_to_next_activity_km__998': None, 'activity_type__998': 'HC', 'longitude__998': ' 6.860704629276648', 'room__998': 'HT 1100', 'building_code__998': 'HT', 'start_time__998': datetime.time(15, 45), 'year__998': '2013', 'course_code__998': '191103250', 'duration__998': 1.75, 'end_time__998': datetime.time(17, 30), 'latitude__999': '52.23761533457211', 'activity_description__999': 'Project F 191103250', 'date__999': datetime.date(2014, 3, 24), 'activity_name__999': '2A Project F/HC04/01', 'program_code__999': 'WB B', 'distance_to_next_activity_km__999': None, 'activity_type__999': 'HC', 'longitude__999': ' 6.860704629276648', 'room__999': 'HT 1100', 'building_code__999': 'HT', 'start_time__999': datetime.time(15, 45), 'year__999': '2013', 'course_code__999': '191103250', 'duration__999': 1.75, 'end_time__999': datetime.time(17, 30)}]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
import matplotlib.pyplot as plt
activities['distance_to_next_activity_km'].dropna().hist(bins=50)
plt.xlabel('Distance (km)')
plt.ylabel('Frequency')
plt.title('Distribution of Activity Distances')
plt.show()
